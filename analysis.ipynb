L.marker(
#                 [-33.920011, 18.642819],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_6768cc1f409f44f62be3b56abdfce367 = L.marker(
#                 [-34.047464, 18.452499],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_73031e93a17b2fb3622a7f5db25bdaa4 = L.marker(
#                 [-33.947283, 18.575133],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_c32f19cdb9485c6ba4501e5722c59b0a = L.marker(
#                 [-33.991092, 18.444217],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_fd5393f434c8943d2841ef0af4a1e037 = L.marker(
#                 [-33.882677, 18.652075],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_02a64d5da9ca378797eaf30dc0911a4b = L.marker(
#                 [-33.950161, 18.554446],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_fd573ec82b7941d7401824522aaa49ce = L.marker(
#                 [-33.860418, 18.544612],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_73c54064ea6a9e3c2b707a466a9087f9 = L.marker(
#                 [-34.065011, 22.06257],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_1a7f606232b50e025be638b0b3ef9cdc = L.marker(
#                 [-33.95, 18.533333],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_de072cd1661e62612a993cbec656ea8f = L.marker(
#                 [-33.90982, 18.481978],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_ad99ca837b66a73ed1e4a41ad999e951 = L.marker(
#                 [-33.985847, 18.45749],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_7db7b6eb1060e675e78dbaa70e890953 = L.marker(
#                 [-33.934259, 18.378476],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_3732152bbfcebb9cbe0ca20a00829446 = L.marker(
#                 [-34.124867, 18.432759],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_e162fce878b8f24c3726c2944d4926c6 = L.marker(
#                 [-34.01832, 18.441142],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_3b0f05db06fe81e4635942cdc1a6cc3f = L.marker(
#                 [-33.926369, 18.593577],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_62e65119d77ba2985fee97e587fad86a = L.marker(
#                 [-33.978555, 18.50413],
#                 {}
#             ).addTo(map_b8a10d4e5ddb16bb781996d70b02fbe0);
#
#
#             var marker_4744744cac2dc879a76f551e484a5f24 = L.marker(
#                 [-33.994451, 18.595982],

# %%
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86e75d09b692fa206f459506eacc74d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86e75d09b692fa206f459506eacc74d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86e75d09b692fa206f459506eacc74d6 = L.map(
#                 &quot;map_86e75d09b692fa206f459506eacc74d6&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d6b84900c6682ed87a03424dd98ded1 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86e75d09b692fa206f459506eacc74d6);
#
#
#             var circle_3f2378979528a5ca0393d3b21870ddb0 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_86e75d09b692fa206f459506eacc74d6);
#
#
#         var popup_ec413808208865c801532032acc0e3bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1aa33a62016a5f55fc861d741985a486 = $(`&lt;div id=&quot;html_1aa33a62016a5f55fc861d741985a486&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_ec413808208865c801532032acc0e3bc.setContent(html_1aa33a62016a5f55fc861d741985a486);
#
#
#
#         circle_3f2378979528a5ca0393d3b21870ddb0.bindPopup(popup_ec413808208865c801532032acc0e3bc)
#         ;
#
#
#
#
#             var circle_eef8ff8ac85cee904d77c39eb35f2798 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_86e75d09b692fa206f459506eacc74d6);
#
#
#         var popup_228f1dfcac4889ab17b0a5fcf0575a23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a24afaf620ef442c33f8782a3edb4a9 = $(`&lt;div id=&quot;html_6a24afaf620ef442c33f8782a3edb4a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_228f1dfcac4889ab17b0a5fcf0575a23.setContent(html_6a24afaf620ef442c33f8782a3edb4a9);
#
#
#
#         circle_eef8ff8ac85cee904d77c39eb35f2798.bindPopup(popup_228f1dfcac4889ab17b0a5fcf0575a23)
#         ;
#
#
#
#
#             var circle_249908af75de7e6acd550dc92dd8513e = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_86e75d09b692fa206f459506eacc74d6);
#
#
#         var popup_0ff3495d773ff78a96e8982fd59d3f60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b09ac7a6102d16bbc7f46aa9c4ddc257 = $(`&lt;div id=&quot;html_b09ac7a6102d16bbc7f46aa9c4ddc257&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_0ff3495d773ff78a96e8982fd59d3f60.setContent(html_b09ac7a6102d16bbc7f46aa9c4ddc257);
#
#
#
#         circle_249908af75de7e6acd550dc92dd8513e.bindPopup(popup_0ff3495d773ff78a96e8982fd59d3f60)
#         ;
#
#
#
#
#             var circle_1ad57de56c66b70d2a87d2edc8c08fcf = L.circle(
#                 [-33.920011, 18.642819],

# %%
# Adding Classification
map_points = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    # Classify by usage
    if df_suburbs['Oct 2017\nkl/month'][point] <= 8 and df_suburbs['Oct 2017\nkl/month'][point] > 0:
        usage_color = 'green'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 8 and df_suburbs['Oct 2017\nkl/month'][point] <= 10:
        usage_color = '#17cbef'
    elif df_suburbs['Oct 2017\nkl/month'][point] > 10:
        usage_color = 'red'
    else: # Outliers
        usage_color = 'orange'
        
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius=str(df_suburbs['Oct 2017\nkl/month'][point] * 100),
        color=usage_color,
        fill=True,
        opacity=0.8,
        fill_color=usage_color,
        stroke=True,
        weight=1.0
    ).add_to(map_points)
    
map_points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92c3778cd2c5876e3512047fe48b0642 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92c3778cd2c5876e3512047fe48b0642&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92c3778cd2c5876e3512047fe48b0642 = L.map(
#                 &quot;map_92c3778cd2c5876e3512047fe48b0642&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4ad763a285cda72947d265806423754 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_92c3778cd2c5876e3512047fe48b0642);
#
#
#             var circle_8d44ccbd51037b38496feb9e41da91f0 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_92c3778cd2c5876e3512047fe48b0642);
#
#
#         var popup_c9ae83d1c6a8bc39bb22578df5aedb70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a1aa028bf6689f0cd34a6e9168e57d9 = $(`&lt;div id=&quot;html_3a1aa028bf6689f0cd34a6e9168e57d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_c9ae83d1c6a8bc39bb22578df5aedb70.setContent(html_3a1aa028bf6689f0cd34a6e9168e57d9);
#
#
#
#         circle_8d44ccbd51037b38496feb9e41da91f0.bindPopup(popup_c9ae83d1c6a8bc39bb22578df5aedb70)
#         ;
#
#
#
#
#             var circle_1aa6858c1f4d71969bb1a4fda4dafddd = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_92c3778cd2c5876e3512047fe48b0642);
#
#
#         var popup_bdba3a12dad4268c585d85a111c6d51f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0cd7a23bb150b292eed630cd71d5c53 = $(`&lt;div id=&quot;html_b0cd7a23bb150b292eed630cd71d5c53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_bdba3a12dad4268c585d85a111c6d51f.setContent(html_b0cd7a23bb150b292eed630cd71d5c53);
#
#
#
#         circle_1aa6858c1f4d71969bb1a4fda4dafddd.bindPopup(popup_bdba3a12dad4268c585d85a111c6d51f)
#         ;
#
#
#
#
#             var circle_14447d675f3798be070587cf36973e79 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_92c3778cd2c5876e3512047fe48b0642);
#
#
#         var popup_d11cc42edc0558830a3c0e1c5033694b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4f437bdf9ac2c9a4ec0f67245415154 = $(`&lt;div id=&quot;html_f4f437bdf9ac2c9a4ec0f67245415154&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_d11cc42edc0558830a3c0e1c5033694b.setContent(html_f4f437bdf9ac2c9a4ec0f67245415154);
#
#
#
#         circle_14447d675f3798be070587cf36973e79.bindPopup(popup_d11cc42edc0558830a3c0e1c5033694b)
#         ;
#
#
#
#
#             var circle_189694921efde6f9e00dcf7f6f3b43b4 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot

# %%
# Building choropleth map

df_world_countries = pd.read_json('world-countries.json')
df_unemployment = pd.read_csv('unemployment.csv', skiprows=4, delimiter=',')

df_unemployment
# Out:
#      Country Name Country Code  \
# 0           Aruba          ABW
# 1     Afghanistan          AFG
# 2          Angola          AGO
# 3         Albania          ALB
# 4         Andorra          AND
# ..            ...          ...
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 0    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 1    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 2    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 3    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 4    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# ..                                                 ...             ...   ...
# 259  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 260  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 261  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 262  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 263  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
#
#      1961  1962  1963  1964  1965  ...       2010   2011    2012    2013  \
# 0     NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# 1     NaN   NaN   NaN   NaN   NaN  ...   7.821000   8.23   7.936   8.452
# 2     NaN   NaN   NaN   NaN   NaN  ...   9.863000   7.36   7.347   7.331
# 3     NaN   NaN   NaN   NaN   NaN  ...  14.200000  13.98  13.440  15.640
# 4     NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# ..    ...   ...   ...   ...   ...  ...        ...    ...     ...     ...
# 259   NaN   NaN   NaN   NaN   NaN  ...        NaN    NaN     NaN     NaN
# 260   NaN   NaN   NaN   NaN   NaN  ...  17.820000  16.99  15.277  14.163
# 261   NaN   NaN   NaN   NaN   NaN  ...  24.690001  24.65  24.730  24.570
# 262   NaN   NaN   NaN   NaN   NaN  ...  13.190000   9.99   7.850   7.816
# 263   NaN   NaN   NaN   NaN   NaN  ...   5.272000   5.37   5.328   5.205
#
#        2014    2015       2016    2017       2018  Unnamed: 63
# 0       NaN     NaN        NaN     NaN        NaN          NaN
# 1     8.706   8.864   8.841000   8.837   8.808000          NaN
# 2     7.306   7.281   7.724000   8.167   8.543000          NaN
# 3    17.490  17.080  15.220000  13.867  15.132000          NaN
# 4       NaN     NaN        NaN     NaN        NaN          NaN
# ..      ...     ...        ...     ...        ...          ...
# 259     NaN     NaN        NaN     NaN        NaN          NaN
# 260  13.470  13.807  13.729000  14.036  14.167000          NaN
# 261  24.900  25.160  26.549999  27.330  27.372999          NaN
# 262   7.783   7.750   7.777000   7.792   7.797000          NaN
# 263   5.135   5.086   5.046000   5.011   4.985000          NaN
#
# [264 rows x 64 columns]

# %%
df_unemployment_2018 = df_unemployment[['Country Name', 'Country Code', '2018']]
df_unemployment_2018.head(10)
# Out:
#            Country Name Country Code       2018
# 0                 Aruba          ABW        NaN
# 1           Afghanistan          AFG   8.808000
# 2                Angola          AGO   8.543000
# 3               Albania          ALB  15.132000
# 4               Andorra          AND        NaN
# 5            Arab World          ARB   9.808109
# 6  United Arab Emirates          ARE   1.710000
# 7             Argentina          ARG   8.162000
# 8               Armenia          ARM  18.275999
# 9        American Samoa          ASM        NaN

# %%
# Remove nulls

df_unemployment_2018_clean = df_unemployment_2018.dropna()
df_unemployment_2018_clean.head(10)
# Out:
#             Country Name Country Code       2018
# 1            Afghanistan          AFG   8.808000
# 2                 Angola          AGO   8.543000
# 3                Albania          ALB  15.132000
# 5             Arab World          ARB   9.808109
# 6   United Arab Emirates          ARE   1.710000
# 7              Argentina          ARG   8.162000
# 8                Armenia          ARM  18.275999
# 11             Australia          AUS   5.474000
# 12               Austria          AUT   5.387000
# 13            Azerbaijan          AZE   5.037000

# %%
df_unemployment_2018_clean.shape
# Out:
# (233, 3)

# %%
# prepare data for our map
legendTitle = 'Unemployment rate per country 2018 (%)'

# Data to plot country code and value
data_unemployment = df_unemployment_2018_clean[['Country Code', '2018']]

data_unemployment.head()
# Out:
#   Country Code       2018
# 1          AFG   8.808000
# 2          AGO   8.543000
# 3          ALB  15.132000
# 5          ARB   9.808109
# 6          ARE   1.710000

# %%
# Setup the map
map_unemployment = folium.Map(location=[8.7832, 34.5085], zoom_start=3)


map_unemployment.choropleth(geo_data='world-countries.json',
                           data=data_unemployment,
                           columns=['Country Code', '2018'],
                           key_on='feature.id',
                           fill_color='YlOrRd',
                           fill_opacity=0.7,
                           line_opacity=0.2,
                           legend_name=legendTitle)

map_unemployment
# Out:
# c:\Users\erolg\AppData\Local\Programs\Python\Python311\Lib\site-packages\folium\folium.py:465: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ceb8c1426aafbda7c8ec3b4002b7a15a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ceb8c1426aafbda7c8ec3b4002b7a15a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ceb8c1426aafbda7c8ec3b4002b7a15a = L.map(
#                 &quot;map_ceb8c1426aafbda7c8ec3b4002b7a15a&quot;,
#                 {
#                     center: [8.7832, 34.5085],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4512ff0ebfb868509cd2b4e68f87857d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ceb8c1426aafbda7c8ec3b4002b7a15a);
#
#
#             var choropleth_b7e2a383ac3d1b8169985bcf96854b89 = L.featureGroup(
#                 {}
#             ).addTo(map_ceb8c1426aafbda7c8ec3b4002b7a15a);
#
#
#         function geo_json_f412ae8ca0063fd797771c7f2f6264df_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Afghanistan&quot;: case &quot;Angola&quot;: case &quot;Argentina&quot;: case &quot;Australia&quot;: case &quot;Austria&quot;: case &quot;Azerbaijan&quot;: case &quot;Belgium&quot;: case &quot;Burkina Faso&quot;: case &quot;Bulgaria&quot;: case &quot;Belize&quot;: case &quot;Brunei&quot;: case &quot;Central African Republic&quot;: case &quot;Canada&quot;: case &quot;Chile&quot;: case &quot;Colombia&quot;: case &quot;Costa Rica&quot;: case &quot;Djibouti&quot;: case &quot;Denmark&quot;: case &quot;Dominican Republic&quot;: case &quot;Eritrea&quot;: case &quot;Estonia&quot;: case &quot;Ethiopia&quot;: case &quot;Finland&quot;: case &quot;Fiji&quot;: case &quot;France&quot;: case &quot;Gambia&quot;: case &quot;Guinea Bissau&quot;: case &quot;Equatorial Guinea&quot;: case &quot;Croatia&quot;: case &quot;Ireland&quot;: case &quot;Iraq&quot;: case &quot;Kazakhstan&quot;: case &quot;Kyrgyzstan&quot;: case &quot;Lebanon&quot;: case &quot;Lithuania&quot;: case &quot;Luxembourg&quot;: case &quot;Latvia&quot;: case &quot;Morocco&quot;: case &quot;Mali&quot;: case &quot;Mongolia&quot;: case &quot;Malawi&quot;: case &quot;Nigeria&quot;: case &quot;New Zealand&quot;: case &quot;Portugal&quot;: case &quot;Russia&quot;: case &quot;Saudi Arabia&quot;: case &quot;Somalia&quot;: case &quot;Suriname&quot;: case &quot;Slovakia&quot;: case &quot;Slovenia&quot;: case &quot;Sweden&quot;: case &quot;Chad&quot;: case &quot;Trinidad and Tobago&quot;: case &quot;Ukraine&quot;: case &quot;Uruguay&quot;: case &quot;Uzbekistan&quot;: case &quot;Venezuela&quot;: case &quot;Vanuatu&quot;: case &quot;Zambia&quot;: case &quot;Zimbabwe&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Albania&quot;: case &quot;Armenia&quot;: case &quot;Botswana&quot;: case &quot;Spain&quot;: case &quot;Jordan&quot;: case &quot;Libya&quot;: case &quot;Montenegro&quot;: case &quot;New Caledonia&quot;: case &quot;Syria&quot;: case &quot;Tunisia&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Antarctica&quot;: case &quot;French Southern and Antarctic Lands&quot;: case &quot;Northern Cyprus&quot;: case &quot;Falkland Islands&quot;: case &quot;Greenland&quot;: case &quot;Kosovo&quot;: case &quot;Western Sahara&quot;: case &quot;South Sudan&quot;: case &quot;Somaliland&quot;: case &quot;Taiwan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;The Bahamas&quot;: case &quot;Brazil&quot;: case &quot;Republic of the Congo&quot;: case &quot;Cyprus&quot;: case &quot;Algeria&quot;: case &quot;Egypt&quot;: case &quot;Georgia&quot;: case &quot;Guyana&quot;: case &quot;Haiti&quot;: case &quot;Iran&quot;: case &quot;Italy&quot;: case &quot;Jamaica&quot;: case &quot;Kenya&quot;: case &quot;Mauritania&quot;: case &quot;Puerto Rico&quot;: case &quot;Sudan&quot;: case &quot;Republic of Serbia&quot;: case &quot;Tajikistan&quot;: case &quot;Turkey&quot;: case &quot;Yemen&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bosnia and Herzegovina&quot;: case &quot;Lesotho&quot;: case &quot

# %%
# Measuring Boundries

df_damLevels = pd.read_csv('DamLevels.txt', delimiter=',')

df_damLevels.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras Dam-Lower        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras Dam-Upper        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear
# 0      73.7      75.2      49.9
# 1      50.2      51.7      35.6
# 2      70.0      69.8      92.4
# 3      40.9      41.9      10.6
# 4      65.6      67.5      15.5

# %%
df_location = pd.read_csv('damLocations.txt', delimiter=',')

df_location.head()
# Out:
#                    Dam   Latitude  Longitude
# 0       Berg River Dam -33.925000  19.060833
# 1  Steenbras Dam-Upper -34.166300  18.910000
# 2  Steenbras Dam-Lower -34.179722  18.876389
# 3  Theewaterskloof Dam -34.078100  19.289200
# 4         Voelvlei Dam -33.337500  19.033600

# %%
# Join the two dataframes on the dam field
df_damData = pd.merge(df_damLevels, df_location, on='Dam', how='left')

df_damData.head()
# Out:
#                    Dam                  River  Photo  Indicators    FSC  \
# 0       Berg River Dam             Berg River  Photo  Indicators  127.1
# 1  Steenbras Dam-Lower        Steenbras River  Photo  Indicators   33.9
# 2  Steenbras Dam-Upper        Steenbras River  Photo  Indicators   31.9
# 3  Theewaterskloof Dam  Riviersonderend River  Photo  Indicators  479.3
# 4         Voelvlei Dam         Voelvlei River  Photo  Indicators  158.6
#
#    ThisWeek  LastWeek  LastYear   Latitude  Longitude
# 0      73.7      75.2      49.9 -33.925000  19.060833
# 1      50.2      51.7      35.6 -34.179722  18.876389
# 2      70.0      69.8      92.4 -34.166300  18.910000
# 3      40.9      41.9      10.6 -34.078100  19.289200
# 4      65.6      67.5      15.5 -33.337500  19.033600

# %%
# Prepare data to plot
df_dams_locations = df_damData[['Latitude', 'Longitude']]
dams_location_list = df_dams_locations.values.tolist()
dams_location_list_size = len(dams_location_list)
dams_location_list_size
# Out:
# 6

# %%
map_dams = folium.Map(location=[-33.925, 18.625], zoom_start=10)
for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_dams)
    
map_dams
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7a885b9a28e63c7fdb50a568d4489dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7a885b9a28e63c7fdb50a568d4489dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7a885b9a28e63c7fdb50a568d4489dd = L.map(
#                 &quot;map_e7a885b9a28e63c7fdb50a568d4489dd&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffe4fac6ccf7cf53c45fee981c4c9fe0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e7a885b9a28e63c7fdb50a568d4489dd);
#
#
#             var marker_f0fb2f12e432adc00e2ec5f98e729d60 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_e7a885b9a28e63c7fdb50a568d4489dd);
#
#
#         var popup_d90fa1a084e4bff4fe63d1f87636751d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a04237e2f370071eaff6afff5f197ae2 = $(`&lt;div id=&quot;html_a04237e2f370071eaff6afff5f197ae2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_d90fa1a084e4bff4fe63d1f87636751d.setContent(html_a04237e2f370071eaff6afff5f197ae2);
#
#
#
#         marker_f0fb2f12e432adc00e2ec5f98e729d60.bindPopup(popup_d90fa1a084e4bff4fe63d1f87636751d)
#         ;
#
#
#
#
#             var marker_17e93fa35c4c29603b3a3924a646eca9 = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_e7a885b9a28e63c7fdb50a568d4489dd);
#
#
#         var popup_51c20c364bc44899634a8bc3a5719e5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb040190da21830327a1be959593e690 = $(`&lt;div id=&quot;html_bb040190da21830327a1be959593e690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_51c20c364bc44899634a8bc3a5719e5d.setContent(html_bb040190da21830327a1be959593e690);
#
#
#
#         marker_17e93fa35c4c29603b3a3924a646eca9.bindPopup(popup_51c20c364bc44899634a8bc3a5719e5d)
#         ;
#
#
#
#
#             var marker_1e70d804c1cc017e1d5f6a1bef716285 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_e7a885b9a28e63c7fdb50a568d4489dd);
#
#
#         var popup_94dcf03ea0da003d5b6a7d54da02f1d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a50c278a322e4f7665660e171de1fc2 = $(`&lt;div id=&quot;html_6a50c278a322e4f7665660e171de1fc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_94dcf03ea0da003d5b6a7d54da02f1d3.setContent(html_6a50c278a322e4f7665660e171de1fc2);
#
#
#
#         marker_1e70d804c1cc017e1d5f6a1bef716285.bindPopup(popup_94dcf03ea0da003d5b6a7d54da02f1d3)
#         ;
#
#
#
#
#             var marker_fae9810c40b424cc48f41d3ef8072a28 = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_e7a885b9a28e63c7fdb50a568d4489dd);
#
#
#         var popup_7c03d5fd46a69395addd17776ad9a27c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a2f862c11123cebb676c5f0ae83a9bc = $(`&lt;div id=&quot;html_2a2f862c11123cebb676c5f0ae83a9bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_7c03d5fd46a69395addd17776ad9a27c.setContent(html_2a2f862c11123cebb676c5f0ae83a9bc);
#
#
#
#         marker_fae9810c40b424cc48f41d3ef8072a28.bindPopup(popup_7c03d5fd46a69395addd17776ad9a27c)
#         ;
#
#
#
#
#             var marker_90abe05552f751776129ec17d8f8db99 = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_e7a885b9a28e63c7fdb50a568d4489dd);
#
#
#         var popup_bf0489cfe4bd7613c8fca8c9f649eb03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2426794856acf5a51aca5f3778bdf8e7 = $(`&lt;div id=&quot;html_2426794856acf5a51aca5f3778bdf8e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_bf0489cfe4bd7613c8fca8c9f649eb03.setContent(html_2426794856acf5a51aca5f3778bdf8e7);
#
#
#
#         marker_90abe05552f751776129ec17d8f8db99.bindPopup(popup_bf0489cfe4bd7613c8fca8c9f649eb03)
#         ;
#
#
#
#
#             var marker_2142f9c2c0af72dd965153592705638a = L.marker(
#                 [-33.8336, 19.0889],
#                 {}

# %%
map_url = folium.Map(location=[-34.078100, 19.289200],
                    tiles='http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                    zoom_start=12,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community')

for point in range(0, dams_location_list_size):
    folium.Marker(dams_location_list[point], popup=df_damData['Dam'][point]).add_to(map_url)

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4590a14dc8d5b2370dcdaaa1a989e6b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4590a14dc8d5b2370dcdaaa1a989e6b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4590a14dc8d5b2370dcdaaa1a989e6b7 = L.map(
#                 &quot;map_4590a14dc8d5b2370dcdaaa1a989e6b7&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e767c8b8dc6b6b6bfaf05369a7eef259 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4590a14dc8d5b2370dcdaaa1a989e6b7);
#
#
#             var marker_631f3d195431210801c4595f179b5918 = L.marker(
#                 [-33.925, 19.060833],
#                 {}
#             ).addTo(map_4590a14dc8d5b2370dcdaaa1a989e6b7);
#
#
#         var popup_c8a8be9d2c8b5f5fddcb8213535387d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31ba2929d00ac9143b59b55e7147c272 = $(`&lt;div id=&quot;html_31ba2929d00ac9143b59b55e7147c272&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berg River Dam&lt;/div&gt;`)[0];
#                 popup_c8a8be9d2c8b5f5fddcb8213535387d4.setContent(html_31ba2929d00ac9143b59b55e7147c272);
#
#
#
#         marker_631f3d195431210801c4595f179b5918.bindPopup(popup_c8a8be9d2c8b5f5fddcb8213535387d4)
#         ;
#
#
#
#
#             var marker_11b975ebd538c4310c20d98b73bd923f = L.marker(
#                 [-34.179722, 18.876389],
#                 {}
#             ).addTo(map_4590a14dc8d5b2370dcdaaa1a989e6b7);
#
#
#         var popup_667c592cac8c81cf3b28d80be256a271 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dff7a027ea66e48a9294af1282598735 = $(`&lt;div id=&quot;html_dff7a027ea66e48a9294af1282598735&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Lower&lt;/div&gt;`)[0];
#                 popup_667c592cac8c81cf3b28d80be256a271.setContent(html_dff7a027ea66e48a9294af1282598735);
#
#
#
#         marker_11b975ebd538c4310c20d98b73bd923f.bindPopup(popup_667c592cac8c81cf3b28d80be256a271)
#         ;
#
#
#
#
#             var marker_abdd769966dc6f35599b416623303137 = L.marker(
#                 [-34.1663, 18.91],
#                 {}
#             ).addTo(map_4590a14dc8d5b2370dcdaaa1a989e6b7);
#
#
#         var popup_cc768c54837728082334d33c41257b26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f6e9fc523706a54e5ae027873a6b869 = $(`&lt;div id=&quot;html_2f6e9fc523706a54e5ae027873a6b869&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steenbras Dam-Upper&lt;/div&gt;`)[0];
#                 popup_cc768c54837728082334d33c41257b26.setContent(html_2f6e9fc523706a54e5ae027873a6b869);
#
#
#
#         marker_abdd769966dc6f35599b416623303137.bindPopup(popup_cc768c54837728082334d33c41257b26)
#         ;
#
#
#
#
#             var marker_d72e93f021efe4eb1ac3c970f6caeecf = L.marker(
#                 [-34.0781, 19.2892],
#                 {}
#             ).addTo(map_4590a14dc8d5b2370dcdaaa1a989e6b7);
#
#
#         var popup_7f984a6cd6f4148103bad1214c668edf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74c596e7e4848016aa4686b30ddf9f3f = $(`&lt;div id=&quot;html_74c596e7e4848016aa4686b30ddf9f3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Theewaterskloof Dam&lt;/div&gt;`)[0];
#                 popup_7f984a6cd6f4148103bad1214c668edf.setContent(html_74c596e7e4848016aa4686b30ddf9f3f);
#
#
#
#         marker_d72e93f021efe4eb1ac3c970f6caeecf.bindPopup(popup_7f984a6cd6f4148103bad1214c668edf)
#         ;
#
#
#
#
#             var marker_2ce818e8d3c7b855cd161e9bbd66c1de = L.marker(
#                 [-33.3375, 19.0336],
#                 {}
#             ).addTo(map_4590a14dc8d5b2370dcdaaa1a989e6b7);
#
#
#         var popup_c1373d6ef5ce9a36903039e8aafdf2ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f00a5531d87c17c7c7bb5d0d5a71f804 = $(`&lt;div id=&quot;html_f00a5531d87c17c7c7bb5d0d5a71f804&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Voelvlei Dam&lt;/div&gt;`)[0];
#                 popup_c1373d6ef5ce9a36903039e8aafdf2ee.setContent(html_f00a5531d87c17c7c7bb5d0d5a71f804);
#
#
#
#         marker_2ce818e8d3c7b855cd161e9bbd66c1de.bindPopup(popup_c1373d6ef5ce9a36903039e8aafdf2ee)
#         ;
#
#
#
#
#             var marker_19c7c680c4ba2bec51e916659765c499 = L.marker(
#                 [-33.8336, 19.0889],
#                 {}
#             ).addTo(map_4590a14dc8d5b2370dcdaaa1a989e6b7);

# %%
from folium.plugins import MeasureControl

map_url.add_child(MeasureControl())

map_url
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b659ae9217473ece47b3e1d41fc6216 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b659ae9217473ece47b3e1d41fc6216&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b659ae9217473ece47b3e1d41fc6216 = L.map(
#                 &quot;map_1b659ae9217473ece47b3e1d41fc6216&quot;,
#                 {
#                     center: [-34.0781, 19.2892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cde6a5865e0c83a5bed2ed14e22c25e8 = L.tileLayer(
#                 &quot;http://services.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b659ae9217473ece47b3e1d41fc6216);
#
#
#             var measure_control_8145349a872d5848242dbead0860eb04 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;topright&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_1b659ae9217473ece47b3e1d41fc6216.addControl(measure_control_8145349a872d5848242dbead0860eb04);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add Layer Control
map_layers = map_points

add = '/MapServer/tile/{z}/{y}/{x}'
ESRI = dict(World_Ocean_Base='http://services.arcgisonline.com/arcgis/rest/services/Ocean/World_Ocean_Base',
            World_Navigation_Charts='http://services.arcgisonline.com/ArcGIS/rest/services/Specialty/World_Navigation_Charts',
            NatGeo_World_Map='http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer',
            World_Imagery='http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer',
            World_Physical_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Physical_Map/MapServer',
            World_Shaded_Relief='http://services.arcgisonline.com/arcgis/rest/services/World_Shaded_Relief/MapServer',
            World_Street_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Street_Map/MapServer',
            World_Terrain_Base='http://services.arcgisonline.com/arcgis/rest/services/World_Terrain_Base/MapServer',
            World_Topo_Map='http://services.arcgisonline.com/arcgis/rest/services/World_Topo_Map/MapServer')


for tile_name, tile_url in ESRI.items():
    tile_url += add
    folium.TileLayer(tile_url,
                    name=tile_name,
                    attr='Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community').add_to(map_points)
    

folium.LayerControl().add_to(map_layers)

map_layers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92c3778cd2c5876e3512047fe48b0642 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92c3778cd2c5876e3512047fe48b0642&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92c3778cd2c5876e3512047fe48b0642 = L.map(
#                 &quot;map_92c3778cd2c5876e3512047fe48b0642&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4ad763a285cda72947d265806423754 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_92c3778cd2c5876e3512047fe48b0642);
#
#
#             var circle_8d44ccbd51037b38496feb9e41da91f0 = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1100&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_92c3778cd2c5876e3512047fe48b0642);
#
#
#         var popup_c9ae83d1c6a8bc39bb22578df5aedb70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a1aa028bf6689f0cd34a6e9168e57d9 = $(`&lt;div id=&quot;html_3a1aa028bf6689f0cd34a6e9168e57d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_c9ae83d1c6a8bc39bb22578df5aedb70.setContent(html_3a1aa028bf6689f0cd34a6e9168e57d9);
#
#
#
#         circle_8d44ccbd51037b38496feb9e41da91f0.bindPopup(popup_c9ae83d1c6a8bc39bb22578df5aedb70)
#         ;
#
#
#
#
#             var circle_1aa6858c1f4d71969bb1a4fda4dafddd = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1000&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_92c3778cd2c5876e3512047fe48b0642);
#
#
#         var popup_bdba3a12dad4268c585d85a111c6d51f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0cd7a23bb150b292eed630cd71d5c53 = $(`&lt;div id=&quot;html_b0cd7a23bb150b292eed630cd71d5c53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_bdba3a12dad4268c585d85a111c6d51f.setContent(html_b0cd7a23bb150b292eed630cd71d5c53);
#
#
#
#         circle_1aa6858c1f4d71969bb1a4fda4dafddd.bindPopup(popup_bdba3a12dad4268c585d85a111c6d51f)
#         ;
#
#
#
#
#             var circle_14447d675f3798be070587cf36973e79 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;1300&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_92c3778cd2c5876e3512047fe48b0642);
#
#
#         var popup_d11cc42edc0558830a3c0e1c5033694b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4f437bdf9ac2c9a4ec0f67245415154 = $(`&lt;div id=&quot;html_f4f437bdf9ac2c9a4ec0f67245415154&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_d11cc42edc0558830a3c0e1c5033694b.setContent(html_f4f437bdf9ac2c9a4ec0f67245415154);
#
#
#
#         circle_14447d675f3798be070587cf36973e79.bindPopup(popup_d11cc42edc0558830a3c0e1c5033694b)
#         ;
#
#
#
#
#             var circle_189694921efde6f9e00dcf7f6f3b43b4 = L.circle(
#                 [-33.920011, 18.642819],
#                 {&quot

# %%
# Creating Heatmap

from folium.plugins import HeatMap

# Create our point map object
map_heat = folium.Map(location=[-33.925, 18.625], tiles='CartoDB dark_matter', zoom_start=10)

for point in range(0, suburbs_location_list_size):
    folium.Circle(
        location=suburbs_location_list[point],
        popup=df_suburbs['Suburb'][point] + ': ' + str(df_suburbs['Oct 2017\nkl/month'][point]) + ' kL',
        radius='15',
        color='#17cbef',
        fill=True,
        opacity=0.8,
        fill_color='#17cbef',
        stroke=True,
        weight=1.0
    ).add_to(map_heat)
    
# convert to array format for our heatmap
suburbsArray = df_suburbs[['Latitude', 'Longitude']].values

# plot heatmap
map_heat.add_child(HeatMap(suburbsArray))

map_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c42e50283c3e723a22348e944cb8c67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c42e50283c3e723a22348e944cb8c67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c42e50283c3e723a22348e944cb8c67 = L.map(
#                 &quot;map_1c42e50283c3e723a22348e944cb8c67&quot;,
#                 {
#                     center: [-33.925, 18.625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c640b260875ef820b30185029f635092 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c42e50283c3e723a22348e944cb8c67);
#
#
#             var circle_b54de9b44acec7709750cddfe20accef = L.circle(
#                 [-33.96722, 18.50214],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_1c42e50283c3e723a22348e944cb8c67);
#
#
#         var popup_c8661d1977ff6adede1a6163cb06ebfa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_73ff9d6187ee4e4fe910b4b17648124e = $(`&lt;div id=&quot;html_73ff9d6187ee4e4fe910b4b17648124e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ATHLONE: 11 kL&lt;/div&gt;`)[0];
#                 popup_c8661d1977ff6adede1a6163cb06ebfa.setContent(html_73ff9d6187ee4e4fe910b4b17648124e);
#
#
#
#         circle_b54de9b44acec7709750cddfe20accef.bindPopup(popup_c8661d1977ff6adede1a6163cb06ebfa)
#         ;
#
#
#
#
#             var circle_bce90d41dca78fe12c8de69bd2e99ce2 = L.circle(
#                 [-32.705958, 18.485135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_1c42e50283c3e723a22348e944cb8c67);
#
#
#         var popup_777af5ffb5e7a0aa20f2dff3cf5c698b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2aebcbc59a4f58e308ccd62266c50728 = $(`&lt;div id=&quot;html_2aebcbc59a4f58e308ccd62266c50728&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AURORA: 10 kL&lt;/div&gt;`)[0];
#                 popup_777af5ffb5e7a0aa20f2dff3cf5c698b.setContent(html_2aebcbc59a4f58e308ccd62266c50728);
#
#
#
#         circle_bce90d41dca78fe12c8de69bd2e99ce2.bindPopup(popup_777af5ffb5e7a0aa20f2dff3cf5c698b)
#         ;
#
#
#
#
#             var circle_d48c9a6f95e0621a5c346e9f6e20a959 = L.circle(
#                 [-33.927953, 18.382592],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#17cbef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#17cbef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: &quot;15&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 1.0}
#             ).addTo(map_1c42e50283c3e723a22348e944cb8c67);
#
#
#         var popup_bc6f898997c0438c4fd77eaba85f70dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8731e82d48b4de8b9c6b1a679f7ed10c = $(`&lt;div id=&quot;html_8731e82d48b4de8b9c6b1a679f7ed10c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BANTRY BAY: 13 kL&lt;/div&gt;`)[0];
#                 popup_bc6f898997c0438c4fd77eaba85f70dd.setContent(html_8731e82d48b4de8b9c6b1a679f7ed10c);
#
#
#
#         circle_d48c9a6f95e0621a5c346e9f6e20a959.bindPopup(popup_bc6f898997c0438c4fd77eaba85f70dd)
